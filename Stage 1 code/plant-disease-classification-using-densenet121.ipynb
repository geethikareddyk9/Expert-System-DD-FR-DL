# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
#for dirname, _, filenames in os.walk('/kaggle/input'):
    #for filename in filenames:
       # print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import cv2
import os
from tqdm import tqdm
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from keras.models import Model,Sequential, Input, load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.applications import DenseNet121
from keras.applications import DenseNet201

# %%
disease_types = ['Tomato_Bacterial_spot','Tomato_Early_blight','Tomato_Late_blight','Tomato_Leaf_Mold','Tomato_Septoria_leaf_spot','Tomato_Spider_mites_Two_spotted_spider_mite','Tomato__Target_Spot','Tomato__Tomato_YellowLeaf__Curl_Virus','Tomato__Tomato_mosaic_virus','Tomato_healthy']
data_dir = '../input/plantdisease/PlantVillage/'
train_dir = os.path.join(data_dir)
#test_dir = os.path.join(data_dir, 'test')

# %%
train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])
        
train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])
train.tail()
# Out:
#                                                     File  DiseaseID  \
# 16007  Tomato_healthy/55bcfcce-70f4-4634-8107-0a8207d...          9
# 16008  Tomato_healthy/81024038-40ff-40c4-b8f4-4a48b08...          9
# 16009  Tomato_healthy/058ade43-2361-4039-bbe5-0ac6618...          9
# 16010  Tomato_healthy/2e485f1d-5aa5-4d56-8733-9625ed4...          9
# 16011  Tomato_healthy/d984f436-1fde-4221-9563-82f55a4...          9
#
#          Disease Type
# 16007  Tomato_healthy
# 16008  Tomato_healthy
# 16009  Tomato_healthy
# 16010  Tomato_healthy
# 16011  Tomato_healthy

# %%
train.sample(10)
# Out:
#                                                     File  DiseaseID  \
# 13197  Tomato__Tomato_YellowLeaf__Curl_Virus/35b953f7...          7
# 5002   Tomato_Late_blight/18ab423e-c11a-4800-a84b-459...          2
# 4797   Tomato_Late_blight/1e0c01b6-5d75-47ea-b455-c95...          2
# 15162  Tomato_healthy/ed4e4d41-ed9d-4e62-9cc8-33fadd7...          9
# 9946   Tomato__Target_Spot/b969f29a-d7bd-4be8-a048-62...          6
# 9678   Tomato__Target_Spot/a1ff0477-0781-4699-ae03-25...          6
# 5196   Tomato_Leaf_Mold/416808ef-060a-4c7c-9e0c-1dc72...          3
# 3986   Tomato_Late_blight/c1114ce7-8c10-4854-8c07-66b...          2
# 5241   Tomato_Leaf_Mold/fe52f026-be65-43bf-823e-d5fc9...          3
# 13233  Tomato__Tomato_YellowLeaf__Curl_Virus/953e9f0e...          7
#
#                                 Disease Type
# 13197  Tomato__Tomato_YellowLeaf__Curl_Virus
# 5002                      Tomato_Late_blight
# 4797                      Tomato_Late_blight
# 15162                         Tomato_healthy
# 9946                     Tomato__Target_Spot
# 9678                     Tomato__Target_Spot
# 5196                        Tomato_Leaf_Mold
# 3986                      Tomato_Late_blight
# 5241                        Tomato_Leaf_Mold
# 13233  Tomato__Tomato_YellowLeaf__Curl_Virus

# %%
train.head(10)
# Out:
#                                                 File  DiseaseID  \
# 0  Tomato_Bacterial_spot/a129e8eb-e2b4-4a8a-a509-...          0
# 1  Tomato_Bacterial_spot/21833eb1-b84e-4471-816b-...          0
# 2  Tomato_Bacterial_spot/67c8bbdb-ba79-4c64-897f-...          0
# 3  Tomato_Bacterial_spot/79d8d47a-c8c9-450d-a567-...          0
# 4  Tomato_Bacterial_spot/4436edf6-8c6d-4cc5-b973-...          0
# 5  Tomato_Bacterial_spot/68a2eeb4-4fbd-43bc-ba7f-...          0
# 6  Tomato_Bacterial_spot/6d672985-36f0-48ad-b956-...          0
# 7  Tomato_Bacterial_spot/47d90e2b-bd1b-4b84-94dd-...          0
# 8  Tomato_Bacterial_spot/c9c0a326-c094-4cea-94cb-...          0
# 9  Tomato_Bacterial_spot/5065cba2-6f5c-44e9-886d-...          0
#
#             Disease Type
# 0  Tomato_Bacterial_spot
# 1  Tomato_Bacterial_spot
# 2  Tomato_Bacterial_spot
# 3  Tomato_Bacterial_spot
# 4  Tomato_Bacterial_spot
# 5  Tomato_Bacterial_spot
# 6  Tomato_Bacterial_spot
# 7  Tomato_Bacterial_spot
# 8  Tomato_Bacterial_spot
# 9  Tomato_Bacterial_spot

# %%
# Randomize the order of training set
SEED = 42
train = train.sample(frac=1, random_state=SEED) 
train.index = np.arange(len(train)) # Reset indices
train.head()
# Out:
#                                                 File  DiseaseID  \
# 0  Tomato_healthy/67549f03-2c86-44b7-9730-32d4a23...          9
# 1  Tomato_Septoria_leaf_spot/6c4377ee-cf37-4ca9-a...          4
# 2  Tomato__Target_Spot/34edeb32-db7b-4885-b55f-5a...          6
# 3  Tomato_Septoria_leaf_spot/eb02f238-fac6-434a-8...          4
# 4  Tomato_Spider_mites_Two_spotted_spider_mite/41...          5
#
#                                   Disease Type
# 0                               Tomato_healthy
# 1                    Tomato_Septoria_leaf_spot
# 2                          Tomato__Target_Spot
# 3                    Tomato_Septoria_leaf_spot
# 4  Tomato_Spider_mites_Two_spotted_spider_mite

# %% [markdown]
# Setting a random seed is useful when you want to ensure reproducibility. If you use the same seed value, you'll get the same random order every time you run the code, which can be beneficial for debugging, testing, or when you want others to obtain the same results.

# %% [markdown]
# If we just split data without shuffling, it will give good performance on the training dataset but poor performance on testing. For that, we need to do shuffling of data. So, if we use random_state then we can avoid this problem. When we split data, we want consistence in the result of the dataset every time.

# %%
# Plot a histogram
plt.hist(train['DiseaseID'])
plt.title('Frequency Histogram of Species')
plt.figure(figsize=(12, 12))
plt.show()

# %%
# Display images for different species
def plot_defects(defect_types, rows, cols):
    fig, ax = plt.subplots(rows, cols, figsize=(12, 12))
    defect_files = train['File'][train['Disease Type'] == defect_types].values
    n = 0
    for i in range(rows):
        for j in range(cols):
            image_path = os.path.join(data_dir, defect_files[n])
            ax[i, j].set_xticks([])
            ax[i, j].set_yticks([])
            ax[i, j].imshow(cv2.imread(image_path))
            n += 1
# Displays first n images of class from training set
plot_defects('Tomato_Bacterial_spot', 5, 5)

# %%
IMAGE_SIZE = 64

def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath)) # Loading a color image is the default flag
# Resize image to target size
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %%
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))
# Normalize the data
X_Train = X_train / 255.
print('Train Shape: {}'.format(X_Train.shape))
# Out:
# 16012it [02:55, 90.98it/s]
# Train Shape: (16012, 64, 64, 3)

# %%
# import cv2

# def apply_histogram_equalization(image):
#     hsv = cv2.cvtColor(image, cv2.COLOR_RGB2HSV)
#     hsv[:,:,2] = cv2.equalizeHist(hsv[:,:,2])
#     return cv2.cvtColor(hsv, cv2.COLOR_HSV2RGB)

# %%
Y_train = train['DiseaseID'].values
Y_train = to_categorical(Y_train, num_classes=15)

# %% [markdown]
# In summary, using .values converts a Pandas Series to a NumPy array, and this can be beneficial when working with certain machine learning libraries or numerical operations.

# %%
BATCH_SIZE = 64

# train 70 , val 20, test 10

# Split the train,test validation sets 
X_train, X_temp, Y_train, Y_temp = train_test_split(X_Train, Y_train, test_size=0.3, random_state=SEED)
X_test, X_val, Y_test, Y_val = train_test_split(X_temp, Y_temp, test_size=1/3, random_state = SEED)

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 15))
for i in range(3):
    ax[i].set_axis_off()
    ax[i].imshow(X_train[i])
    ax[i].set_title(disease_types[np.argmax(Y_train[i])])

# %%
EPOCHS = 50
SIZE=64
N_ch=3

# %%
def build_densenet():
    densenet = DenseNet121(weights='imagenet', include_top=False)

    input = Input(shape=(SIZE, SIZE, N_ch))
    x = Conv2D(3, (3, 3), padding='same')(input)
    
    x = densenet(x)
    
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(512, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # multi output
    output = Dense(15,activation = 'softmax', name='root')(x)
 

    # model
    model = Model(input,output)
    
    optimizer = Adam(lr=0.002, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=0.0)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    model.summary()
    
    return model

# %%
model = build_densenet()
annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
# Generates batches of image data with data augmentation
datagen = ImageDataGenerator(rotation_range=360, # Degree range for random rotations
                        width_shift_range=0.2, # Range for random horizontal shifts
                        height_shift_range=0.2, # Range for random vertical shifts
                        zoom_range=0.2, # Range for random zoom
                        horizontal_flip=True, # Randomly flip inputs horizontally
                        vertical_flip=True) # Randomly flip inputs vertically

datagen.fit(X_train)
# Fits the model on batches with real-time data augmentation
hist = model.fit_generator(datagen.flow(X_train, Y_train, batch_size=BATCH_SIZE),
               steps_per_epoch=X_train.shape[0] // BATCH_SIZE,
               epochs=EPOCHS,
               verbose=2,
               callbacks=[annealer, checkpoint],
               validation_data=(X_val, Y_val))
# Out:
# Downloading data from https://github.com/keras-team/keras-applications/releases/download/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 0s 0us/step
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 64, 64, 3)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 3)         84
# _________________________________________________________________
# densenet121 (Model)          multiple                  7037504
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 1024)              0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# root (Dense)                 (None, 15)                7695
# =================================================================
# Total params: 7,576,227
# Trainable params: 7,489,507
# Non-trainable params: 86,720
# _________________________________________________________________
# Epoch 1/50
#  - 102s - loss: 2.6410 - accuracy: 0.3181 - val_loss: 1.9505 - val_accuracy: 0.3908
#
# Epoch 00001: val_loss improved from inf to 1.95055, saving model to model.h5
# Epoch 2/50
#  - 33s - loss: 1.1689 - accuracy: 0.6418 - val_loss: 1.1264 - val_accuracy: 0.6673
#
# Epoch 00002: val_loss improved from 1.95055 to 1.12643, saving model to model.h5
# Epoch 3/50
#  - 33s - loss: 0.7276 - accuracy: 0.7666 - val_loss: 0.5407 - val_accuracy: 0.8308
#
# Epoch 00003: val_loss improved from 1.12643 to 0.54066, saving model to model.h5
# Epoch 4/50
#  - 33s - loss: 0.5316 - accuracy: 0.8262 - val_loss: 2.1990 - val_accuracy: 0.4794
#
# Epoch 00004: val_loss did not improve from 0.54066
# Epoch 5/50
#  - 33s - loss: 0.4330 - accuracy: 0.8597 - val_loss: 0.2718 - val_accuracy: 0.9076
#
# Epoch 00005: val_loss improved from 0.54066 to 0.27178, saving model to model.h5
# Epoch 6/50
#  - 33s - loss: 0.3538 - accuracy: 0.8823 - val_loss: 0.3130 - val_accuracy: 0.8958
#
# Epoch 00006: val_loss did not improve from 0.27178
# Epoch 7/50
#  - 33s - loss: 0.3281 - accuracy: 0.8953 - val_loss: 0.3830 - val_accuracy: 0.8883
#
# Epoch 00007: val_loss did not improve from 0.27178
# Epoch 8/50
#  - 33s - loss: 0.2696 - accuracy: 0.9130 - val_loss: 0.3625 - val_accuracy: 0.8958
#
# Epoch 00008: val_loss did not improve from 0.27178
# Epoch 9/50
#  - 33s - loss: 0.2466 - accuracy: 0.9237 - val_loss: 0.4205 - val_accuracy: 0.8758
#
# Epoch 00009: val_loss did not improve from 0.27178
# Epoch 10/50
#  - 33s - loss: 0.2165 - accuracy: 0.9289 - val_loss: 0.2544 - val_accuracy: 0.9195
#
# Epoch 00010: val_loss improved from 0.27178 to 0.25435, saving model to model.h5
# Epoch 11/50
#  - 33s - loss: 0.2309 - accuracy: 0.9263 - val_loss: 0.2950 - val_accuracy: 0.9051
#
# Epoch 00011: val_loss did not improve from 0.25435
# Epoch 12/50
#  - 33s - loss: 0.1724 - accuracy: 0.9403 - val_loss: 0.2407 - val_accuracy: 0.9195
#
# Epoch 00012: val_loss improved from 0.25435 to 0.24071, saving model to model.h5
# Epoch 13/50
#  - 33s - loss: 0.1660 - accuracy: 0.9462 - val_loss: 0.4801 - val_accuracy: 0.8683
#
# Epoch 00013: val_loss did not improve from 0.24071
# Epoch 14/50
#  - 33s - loss: 0.1797 - accuracy: 0.9431 - val_loss: 0.2050 - val_accuracy: 0.9313
#
# Epoch 00014: val_loss improved from 0.24071 to 0.20497, saving model to model.h5
# Epoch 15/50
#  - 33s - loss: 0.2083 - accuracy: 0.9371 - val_loss: 1.3344 - val_accuracy: 0.6804
#
# Epoch 00015: val_loss did not improve from 0.20497
# Epoch 16/50
#  - 33s - loss: 0.1662 - accuracy: 0.9483 - val_loss: 1.0574 - val_accuracy: 0.7197
#
# Epoch 00016: val_loss did not improve from 0.20497
# Epoch 17/50
#  - 33s - loss: 0.1473 - accuracy: 0.9542 - val_loss: 1.7028 - val_accuracy: 0.6854
#
# Epoch 00017: val_loss did not improve from 0.20497
# Epoch 18/50
#  - 33s - loss: 0.1376 - accuracy: 0.9529 - val_loss: 0.2976 - val_accuracy: 0.9039
#
# Epoch 00018: val_loss did not improve from 0.20497
# Epoch 19/50
#  - 33s - loss: 0.1181 - accuracy: 0.9605 - val_loss: 0.2206 - val_accuracy: 0.9288
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
#
# Epoch 00019: val_loss did not improve from 0.20497
# Epoch 20/50
#  - 33s - loss: 0.0989 - accuracy: 0.9673 - val_loss: 0.2660 - val_accuracy: 0.9270
#
# Epoch 00020: val_loss did not improve from 0.20497
# Epoch 21/50
#  - 33s - loss: 0.0987 - accuracy: 0.9684 - val_loss: 0.1978 - val_accuracy: 0.9370
#
# Epoch 00021: val_loss improved from 0.20497 to 0.19775, saving model to model.h5
# Epoch 22/50
#  - 33s - loss: 0.0837 - accuracy: 0.9720 - val_loss: 0.1220 - val_accuracy: 0.9600
#
# Epoch 00022: val_loss improved from 0.19775 to 0.12198, saving model to model.h5
# Epoch 23/50
#  - 33s - loss: 0.0861 - accuracy: 0.9690 - val_loss: 0.1417 - val_accuracy: 0.9563
#
# Epoch 00023: val_loss did not improve from 0.12198
# Epoch 24/50
#  - 33s - loss: 0.0749 - accuracy: 0.9752 - val_loss: 0.2648 - val_accuracy: 0.9182
#
# Epoch 00024: val_loss did not improve from 0.12198
# Epoch 25/50
#  - 33s - loss: 0.0709 - accuracy: 0.9766 - val_loss: 0.3544 - val_accuracy: 0.9014
#
# Epoch 00025: val_loss did not improve from 0.12198
# Epoch 26/50
#  - 33s - loss: 0.0743 - accuracy: 0.9753 - val_loss: 0.2635 - val_accuracy: 0.9301
#
# Epoch 00026: val_loss did not improve from 0.12198
# Epoch 27/50
#  - 33s - loss: 0.0708 - accuracy: 0.9769 - val_loss: 0.1462 - val_accuracy: 0.9513
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00027: val_loss did not improve from 0.12198
# Epoch 28/50
#  - 33s - loss: 0.0739 - accuracy: 0.9761 - val_loss: 0.1450 - val_accuracy: 0.9507
#
# Epoch 00028: val_loss did not improve from 0.12198
# Epoch 29/50
#  - 33s - loss: 0.0615 - accuracy: 0.9793 - val_loss: 0.4877 - val_accuracy: 0.8627
#
# Epoch 00029: val_loss did not improve from 0.12198
# Epoch 30/50
#  - 33s - loss: 0.0833 - accuracy: 0.9760 - val_loss: 0.3439 - val_accuracy: 0.8939
#
# Epoch 00030: val_loss did not improve from 0.12198
# Epoch 31/50
#  - 33s - loss: 0.0620 - accuracy: 0.9795 - val_loss: 0.1627 - val_accuracy: 0.9557
#
# Epoch 00031: val_loss did not improve from 0.12198
# Epoch 32/50
#  - 32s - loss: 0.0578 - accuracy: 0.9804 - val_loss: 0.2616 - val_accuracy: 0.9276
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00032: val_loss did not improve from 0.12198
# Epoch 33/50
#  - 32s - loss: 0.0600 - accuracy: 0.9802 - val_loss: 0.1629 - val_accuracy: 0.9519
#
# Epoch 00033: val_loss did not improve from 0.12198
# Epoch 34/50
#  - 32s - loss: 0.0718 - accuracy: 0.9799 - val_loss: 0.3583 - val_accuracy: 0.9076
#
# Epoch 00034: val_loss did not improve from 0.12198
# Epoch 35/50
#  - 32s - loss: 0.0650 - accuracy: 0.9781 - val_loss: 0.0749 - val_accuracy: 0.9738
#
# Epoch 00035: val_loss improved from 0.12198 to 0.07486, saving model to model.h5
# Epoch 36/50
#  - 32s - loss: 0.0683 - accuracy: 0.9806 - val_loss: 0.3151 - val_accuracy: 0.9139
#
# Epoch 00036: val_loss did not improve from 0.07486
# Epoch 37/50
#  - 33s - loss: 0.0613 - accuracy: 0.9812 - val_loss: 0.1613 - val_accuracy: 0.9501
#
# Epoch 00037: val_loss did not improve from 0.07486
# Epoch 38/50
#  - 33s - loss: 0.0708 - accuracy: 0.9772 - val_loss: 0.0778 - val_accuracy: 0.9794
#
# Epoch 00038: val_loss did not improve from 0.07486
# Epoch 39/50
#  - 32s - loss: 0.0555 - accuracy: 0.9814 - val_loss: 0.1109 - val_accuracy: 0.9650
#
# Epoch 00039: val_loss did not improve from 0.07486
# Epoch 40/50
#  - 33s - loss: 0.0646 - accuracy: 0.9796 - val_loss: 0.5850 - val_accuracy: 0.8283
#
# Epoch 00040: val_loss did not improve from 0.07486
# Epoch 41/50
#  - 32s - loss: 0.0748 - accuracy: 0.9766 - val_loss: 0.4187 - val_accuracy: 0.9007
#
# Epoch 00041: val_loss did not improve from 0.07486
# Epoch 42/50
#  - 32s - loss: 0.0554 - accuracy: 0.9804 - val_loss: 0.1416 - val_accuracy: 0.9600
#
# Epoch 00042: val_loss did not improve from 0.07486
# Epoch 43/50
#  - 32s - loss: 0.0533 - accuracy: 0.9811 - val_loss: 0.2130 - val_accuracy: 0.9451
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00043: val_loss did not improve from 0.07486
# Epoch 44/50
#  - 32s - loss: 0.0514 - accuracy: 0.9840 - val_loss: 0.3231 - val_accuracy: 0.8995
#
# Epoch 00044: val_loss did not improve from 0.07486
# Epoch 45/50
#  - 33s - loss: 0.0789 - accuracy: 0.9793 - val_loss: 0.1542 - val_accuracy: 0.9538
#
# Epoch 00045: val_loss did not improve from 0.07486
# Epoch 46/50
#  - 33s - loss: 0.0499 - accuracy: 0.9818 - val_loss: 0.1874 - val_accuracy: 0.9388
#
# Epoch 00046: val_loss did not improve from 0.07486
# Epoch 47/50
#  - 32s - loss: 0.0568 - accuracy: 0.9813 - val_loss: 0.2178 - val_accuracy: 0.9413
#
# Epoch 00047: val_loss did not improve from 0.07486
# Epoch 48/50
#  - 32s - loss: 0.0584 - accuracy: 0.9841 - val_loss: 0.0952 - val_accuracy: 0.9738
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00048: val_loss did not improve from 0.07486
# Epoch 49/50
#  - 32s - loss: 0.0458 - accuracy: 0.9851 - val_loss: 0.0808 - val_accuracy: 0.9738
#
# Epoch 00049: val_loss did not improve from 0.07486
# Epoch 50/50
#  - 32s - loss: 0.0494 - accuracy: 0.9837 - val_loss: 0.1273 - val_accuracy: 0.9688
#
# Epoch 00050: val_loss did not improve from 0.07486

# %%
model = load_model('/kaggle/working/model.h5')
print(model.summary())
final_loss, final_accuracy = model.evaluate(X_test, Y_test)
print('Final Loss: {}, Final Accuracy: {}'.format(final_loss, final_accuracy))
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 64, 64, 3)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 3)         84
# _________________________________________________________________
# densenet121 (Model)          multiple                  7037504
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 1024)              0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# root (Dense)                 (None, 15)                7695
# =================================================================
# Total params: 7,576,227
# Trainable params: 7,489,507
# Non-trainable params: 86,720
# _________________________________________________________________
# None
# 3202/3202 [==============================] - 7s 2ms/step
# Final Loss: 0.07625640183654034, Final Accuracy: 0.972517192363739

# %%
# from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# # Assuming you have predictions for validation data
# Y_val_pred = model.predict(X_val)

# # Convert one-hot encoded labels to class labels
# Y_val_labels = np.argmax(Y_val, axis=1)
# Y_val_pred_labels = np.argmax(Y_val_pred, axis=1)

# # Calculate accuracy
# accuracy = accuracy_score(Y_val_labels, Y_val_pred_labels)
# print('Accuracy: {}'.format(accuracy))

# # Calculate precision, recall, and F1-score
# precision = precision_score(Y_val_labels, Y_val_pred_labels, average='weighted')
# recall = recall_score(Y_val_labels, Y_val_pred_labels, average='weighted')
# f1 = f1_score(Y_val_labels, Y_val_pred_labels, average='weighted')

# print('Precision: {}, Recall: {}, F1 Score: {}'.format(precision, recall, f1))

# # Print classification report
# class_report = classification_report(Y_val_labels, Y_val_pred_labels, target_names=disease_types)
# print('Classification Report:\n', class_report)
# Out:
# Accuracy: 0.9737827715355806
# Precision: 0.9743394480648981, Recall: 0.9737827715355806, F1 Score: 0.9737747909496963
# Classification Report:
#                                               precision    recall  f1-score   support
#
#                       Tomato_Bacterial_spot       0.98      0.97      0.97       217
#                         Tomato_Early_blight       0.94      0.96      0.95        97
#                          Tomato_Late_blight       0.97      0.95      0.96       164
#                            Tomato_Leaf_Mold       1.00      0.97      0.98       101
#                   Tomato_Septoria_leaf_spot       0.99      0.99      0.99       198
# Tomato_Spider_mites_Two_spotted_spider_mite       0.92      0.99      0.95       163
#                         Tomato__Target_Spot       0.96      0.91      0.93       139
#       Tomato__Tomato_YellowLeaf__Curl_Virus       0.99      0.99      0.99       323
#                 Tomato__Tomato_mosaic_virus       1.00      1.00      1.00        39
#                              Tomato_healthy       0.98      1.00      0.99       161
#
#                                    accuracy                           0.97      1602
#                                   macro avg       0.97      0.97      0.97      1602
#                                weighted avg       0.97      0.97      0.97      1602

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_auc_score, classification_report

# Assuming model.predict returns the predicted labels for your test data
Y_pred_test = model.predict(X_test)

# Convert predictions to binary labels
Y_pred_test_classes = np.argmax(Y_pred_test, axis=1)
Y_test_classes = np.argmax(Y_test, axis=1)

# Calculate additional metrics
accuracy_test = accuracy_score(Y_test_classes, Y_pred_test_classes)
precision_test = precision_score(Y_test_classes, Y_pred_test_classes, average='weighted')
recall_test = recall_score(Y_test_classes, Y_pred_test_classes, average='weighted')
f1_test = f1_score(Y_test_classes, Y_pred_test_classes, average='weighted')
# roc_auc_test = roc_auc_score(Y_test_classes, Y_pred_test_classes, multi_class='ovr')
confusion_matrix_test = confusion_matrix(Y_test_classes, Y_pred_test_classes)

# Print final metrics
print('Final Loss: {}, Final Accuracy: {}, Precision: {}, Recall: {}, F1 Score: {}'
      .format(final_loss, final_accuracy, precision_test, recall_test, f1_test))
#               , roc_auc_test))

# Print Confusion Matrix
# print('\nConfusion Matrix:\n', confusion_matrix_test)

# Print classification report
class_report = classification_report(Y_pred_test_classes, Y_test_classes, target_names=disease_types)
print('\n\nClassification Report:\n', class_report)

with open('/kaggle/working/classification_report.txt', 'w') as file:
    file.write(class_report)
# Out:
# Final Loss: 0.07625640183654034, Final Accuracy: 0.972517192363739, Precision: 0.9729649761842459, Recall: 0.9725171767645222, F1 Score: 0.9724751252391955
#
#
# Classification Report:
#                                               precision    recall  f1-score   support
#
#                       Tomato_Bacterial_spot       0.96      0.99      0.97       449
#                         Tomato_Early_blight       0.95      0.91      0.93       204
#                          Tomato_Late_blight       0.97      0.98      0.98       370
#                            Tomato_Leaf_Mold       0.98      0.99      0.99       186
#                   Tomato_Septoria_leaf_spot       0.99      0.99      0.99       337
# Tomato_Spider_mites_Two_spotted_spider_mite       0.98      0.93      0.96       347
#                         Tomato__Target_Spot       0.90      0.96      0.93       266
#       Tomato__Tomato_YellowLeaf__Curl_Virus       0.99      0.98      0.99       646
#                 Tomato__Tomato_mosaic_virus       1.00      1.00      1.00        75
#                              Tomato_healthy       1.00      0.98      0.99       322
#
#                                    accuracy                           0.97      3202
#                                   macro avg       0.97      0.97      0.97      3202
#                                weighted avg       0.97      0.97      0.97      3202

# %%
Y_pred = model.predict(X_val)

Y_pred = np.argmax(Y_pred, axis=1)
Y_true = np.argmax(Y_val, axis=1)

cm = confusion_matrix(Y_true, Y_pred)
plt.figure(figsize=(12, 12))
ax = sns.heatmap(cm, cmap=plt.cm.Greens, annot=True, square=True, xticklabels=disease_types, yticklabels=disease_types)
ax.set_ylabel('Actual', fontsize=40)
ax.set_xlabel('Predicted', fontsize=40)

plt.savefig('/kaggle/working/confusion_matrix.png')

# %%
# accuracy plot 
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.savefig('/kaggle/working/accuracy_plot.png') 
plt.show()

# loss plot
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.savefig('/kaggle/working/loss_plot.png') 
plt.show()

# %% [markdown]
# # Testing Disease Prediction

# %%
from skimage import io
from keras.preprocessing import image
#path='imbalanced/Scratch/Scratch_400.jpg'
img = image.load_img('/kaggle/input/plantdisease/PlantVillage/Potato___Early_blight/0267d4ca-522e-4ca0-b1a2-ce925e5b54a2___RS_Early.B 7020.JPG', grayscale=False, target_size=(64, 64))
show_img=image.load_img('/kaggle/input/plantdisease/PlantVillage/Potato___Early_blight/0267d4ca-522e-4ca0-b1a2-ce925e5b54a2___RS_Early.B 7020.JPG', grayscale=False, target_size=(200, 200))
disease_class = ['Tomato_Bacterial_spot','Tomato_Early_blight','Tomato_Late_blight','Tomato_Leaf_Mold','Tomato_Septoria_leaf_spot','Tomato_Spider_mites_Two_spotted_spider_mite','Tomato__Target_Spot','Tomato__Tomato_YellowLeaf__Curl_Virus','Tomato__Tomato_mosaic_virus','Tomato_healthy']
x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
#x = np.array(x, 'float32')
x /= 255

custom = model.predict(x)
print(custom[0])



#x = x.reshape([64, 64]);

#plt.gray()
plt.imshow(show_img)
plt.savefig('/kaggle/working/prediction_plot.png')
plt.show()

a=custom[0]
ind=np.argmax(a)
        
print('Prediction:',disease_class[ind])
# Out:
# [6.7680077e-08 7.5559181e-01 2.1265849e-01 6.0369046e-03 2.3991413e-02
#  1.0827882e-06 3.7004188e-06 2.6436295e-08 5.7729707e-05 8.5948058e-04
#  2.7422397e-04 1.0472394e-05 1.0010289e-04 6.5775537e-05 3.4865210e-04]
# Prediction: Tomato_Early_blight

# %%
# import urllib.request

# # Set the figure size for the plot
# plt.figure(figsize=(15, 15))

# # Load the trained model
# # model = load_model('/kaggle/working/my_model.h5')

# # Define the image URL
# img_url = "https://www.google.com/imgres?imgurl=https%3A%2F%2Fdoorcountypulse.com%2Fwp-content%2Fuploads%2F2017%2F02%2FEarly-blight.jpg&tbnid=OkaWKnZbFZDOpM&vet=12ahUKEwicpIyAgJyDAxXme2wGHfUrAYwQMygRegQIARBk..i&imgrefurl=https%3A%2F%2Fdoorcountypulse.com%2Fpest-profile-septoria-leaf-spot-early-blight-tomatoes%2F&docid=lj3g3J2UvP1WiM&w=780&h=519&q=tomato%20leaf%20disease%20images%20namely&hl=en&ved=2ahUKEwicpIyAgJyDAxXme2wGHfUrAYwQMygRegQIARBk"

# # Download the image and save it to a file
# filename, headers = urllib.request.urlretrieve(img_url)
# img_path = os.path.join(os.getcwd(), filename)

# try:
#     # Load and preprocess the image
#     img = image.load_img(img_path, target_size=(224, 224))
#     img = image.img_to_array(img)
#     img = np.expand_dims(img, axis=0)
#     # Perform further processing as needed
#     # ...
# except Exception as e:
#     print(f"Error loading the image: {e}")


# # # Load and preprocess the image
# # img = image.load_img(img_path, target_size=(224, 224))
# # img = image.img_to_array(img)
# # img = np.expand_dims(img, axis=0)

# # Predict the class probabilities
# probs = model.predict(img)[0]

# # Get the predicted class index and name
# pred_class_prob = np.argmax(probs)
# pred_class_name = disease_types[pred_class_prob]

# # Print the predicted class name and probability
# print(f'Predicted class: {pred_class_name}')
# print(f'Probability: {probs[pred_class_prob]}')

# # Display the image with the predicted class and probability
# plt.imshow(img[0]/255.)
# plt.axis('off')
# plt.text(10, 20, f'Predicted class: {pred_class_name}\nProbability: {probs[pred_class_prob]:.2f}', fontsize=20, color='red', bbox=dict(facecolor='white', alpha=0.8))
# plt.show()

# %%
# # Load the trained model (uncomment and provide the correct path)
# # model = load_model('/kaggle/working/model.h5')

# # Define the image URL (replace with a direct image URL)
# # img_url = "https://www.google.com/imgres?imgurl=https%3A%2F%2Fdoorcountypulse.com%2Fwp-content%2Fuploads%2F2017%2F02%2FEarly-blight.jpg&tbnid=OkaWKnZbFZDOpM&vet=12ahUKEwicpIyAgJyDAxXme2wGHfUrAYwQMygRegQIARBk..i&imgrefurl=https%3A%2F%2Fdoorcountypulse.com%2Fpest-profile-septoria-leaf-spot-early-blight-tomatoes%2F&docid=lj3g3J2UvP1WiM&w=780&h=519&q=tomato%20leaf%20disease%20images%20namely&hl=en&ved=2ahUKEwicpIyAgJyDAxXme2wGHfUrAYwQMygRegQIARBk"
# # img_url = "https://doorcountypulse.com/wp-content/uploads/2017/02/Early-blight.jpg"

# img_url = "data:image/jpeg;base64,..."

# # Download the image and save it to a file
# filename, headers = urllib.request.urlretrieve(img_url)
# img_path = os.path.join(os.getcwd(), filename)

# try:
#     # Load and preprocess the image
#     img = image.load_img(img_path, target_size=(224, 224))
#     img = image.img_to_array(img)
#     img = np.expand_dims(img, axis=0)
# except Exception as e:
#     print(f"Error loading the image: {e}")

# # Predict the class probabilities
# probs = model.predict(img)[0]

# # Get the predicted class index and name
# pred_class_prob = np.argmax(probs)
# pred_class_name = disease_types[pred_class_prob]

# # Print the predicted class name and probability
# print(f'Predicted class: {pred_class_name}')
# print(f'Probability: {probs[pred_class_prob]}')

# # Display the image with the predicted class and probability
# plt.figure(figsize=(8, 8))
# plt.imshow(img[0] / 255.)
# plt.axis('off')
# plt.text(
#     10, 20,
#     f'Predicted class: {pred_class_name}\nProbability: {probs[pred_class_prob]:.2f}',
#     fontsize=12, color='red', bbox=dict(facecolor='white', alpha=0.8)
# )
# plt.show()
