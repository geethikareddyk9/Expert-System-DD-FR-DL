# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
#for dirname, _, filenames in os.walk('/kaggle/input'):
    #for filename in filenames:
       # print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import cv2
import os
from tqdm import tqdm
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from keras.models import Model,Sequential, Input, load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.applications import DenseNet121
from keras.applications import DenseNet201
from keras.applications import MobileNetV2

# %%
disease_types = ['Tomato_Bacterial_spot','Tomato_Early_blight','Tomato_Late_blight','Tomato_Leaf_Mold','Tomato_Septoria_leaf_spot','Tomato_Spider_mites_Two_spotted_spider_mite','Tomato__Target_Spot','Tomato__Tomato_YellowLeaf__Curl_Virus','Tomato__Tomato_mosaic_virus','Tomato_healthy']
data_dir = '../input/plantdisease/PlantVillage/'
train_dir = os.path.join(data_dir)
#test_dir = os.path.join(data_dir, 'test')

# %%
train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])
        
train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])
train.tail()
# Out:
#                                                     File  DiseaseID  \
# 16007  Tomato_healthy/55bcfcce-70f4-4634-8107-0a8207d...          9
# 16008  Tomato_healthy/81024038-40ff-40c4-b8f4-4a48b08...          9
# 16009  Tomato_healthy/058ade43-2361-4039-bbe5-0ac6618...          9
# 16010  Tomato_healthy/2e485f1d-5aa5-4d56-8733-9625ed4...          9
# 16011  Tomato_healthy/d984f436-1fde-4221-9563-82f55a4...          9
#
#          Disease Type
# 16007  Tomato_healthy
# 16008  Tomato_healthy
# 16009  Tomato_healthy
# 16010  Tomato_healthy
# 16011  Tomato_healthy

# %%
train.sample(10)
# Out:
#                                                     File  DiseaseID  \
# 12917  Tomato__Tomato_YellowLeaf__Curl_Virus/2e2a99f3...          7
# 11313  Tomato__Tomato_YellowLeaf__Curl_Virus/0b0791c1...          7
# 3171   Tomato_Late_blight/dadc7e0f-8caf-4db0-9a05-f4b...          2
# 10299  Tomato__Target_Spot/6c769cf5-f804-4c3b-b156-4a...          6
# 1791   Tomato_Bacterial_spot/01d9fc8d-5083-468d-a583-...          0
# 2179   Tomato_Early_blight/90b9c783-480b-4f9b-a97a-d6...          1
# 14937  Tomato_healthy/2de3b39c-9fbd-4e94-b9e4-3f97dac...          9
# 7278   Tomato_Septoria_leaf_spot/adb55578-5e78-4544-8...          4
# 5110   Tomato_Leaf_Mold/b98b4279-5ffc-4314-a3c4-1fc05...          3
# 3486   Tomato_Late_blight/b8b5b34a-6856-4c79-9681-047...          2
#
#                                 Disease Type
# 12917  Tomato__Tomato_YellowLeaf__Curl_Virus
# 11313  Tomato__Tomato_YellowLeaf__Curl_Virus
# 3171                      Tomato_Late_blight
# 10299                    Tomato__Target_Spot
# 1791                   Tomato_Bacterial_spot
# 2179                     Tomato_Early_blight
# 14937                         Tomato_healthy
# 7278               Tomato_Septoria_leaf_spot
# 5110                        Tomato_Leaf_Mold
# 3486                      Tomato_Late_blight

# %%
train.head(10)
# Out:
#                                                 File  DiseaseID  \
# 0  Tomato_Bacterial_spot/a129e8eb-e2b4-4a8a-a509-...          0
# 1  Tomato_Bacterial_spot/21833eb1-b84e-4471-816b-...          0
# 2  Tomato_Bacterial_spot/67c8bbdb-ba79-4c64-897f-...          0
# 3  Tomato_Bacterial_spot/79d8d47a-c8c9-450d-a567-...          0
# 4  Tomato_Bacterial_spot/4436edf6-8c6d-4cc5-b973-...          0
# 5  Tomato_Bacterial_spot/68a2eeb4-4fbd-43bc-ba7f-...          0
# 6  Tomato_Bacterial_spot/6d672985-36f0-48ad-b956-...          0
# 7  Tomato_Bacterial_spot/47d90e2b-bd1b-4b84-94dd-...          0
# 8  Tomato_Bacterial_spot/c9c0a326-c094-4cea-94cb-...          0
# 9  Tomato_Bacterial_spot/5065cba2-6f5c-44e9-886d-...          0
#
#             Disease Type
# 0  Tomato_Bacterial_spot
# 1  Tomato_Bacterial_spot
# 2  Tomato_Bacterial_spot
# 3  Tomato_Bacterial_spot
# 4  Tomato_Bacterial_spot
# 5  Tomato_Bacterial_spot
# 6  Tomato_Bacterial_spot
# 7  Tomato_Bacterial_spot
# 8  Tomato_Bacterial_spot
# 9  Tomato_Bacterial_spot

# %%
# Randomize the order of training set
SEED = 42
train = train.sample(frac=1, random_state=SEED) 
train.index = np.arange(len(train)) # Reset indices
train.head()
# Out:
#                                                 File  DiseaseID  \
# 0  Tomato_healthy/67549f03-2c86-44b7-9730-32d4a23...          9
# 1  Tomato_Septoria_leaf_spot/6c4377ee-cf37-4ca9-a...          4
# 2  Tomato__Target_Spot/34edeb32-db7b-4885-b55f-5a...          6
# 3  Tomato_Septoria_leaf_spot/eb02f238-fac6-434a-8...          4
# 4  Tomato_Spider_mites_Two_spotted_spider_mite/41...          5
#
#                                   Disease Type
# 0                               Tomato_healthy
# 1                    Tomato_Septoria_leaf_spot
# 2                          Tomato__Target_Spot
# 3                    Tomato_Septoria_leaf_spot
# 4  Tomato_Spider_mites_Two_spotted_spider_mite

# %% [markdown]
# Setting a random seed is useful when you want to ensure reproducibility. If you use the same seed value, you'll get the same random order every time you run the code, which can be beneficial for debugging, testing, or when you want others to obtain the same results.

# %% [markdown]
# If we just split data without shuffling, it will give good performance on the training dataset but poor performance on testing. For that, we need to do shuffling of data. So, if we use random_state then we can avoid this problem. When we split data, we want consistence in the result of the dataset every time.

# %%
# Plot a histogram
plt.hist(train['DiseaseID'])
plt.title('Frequency Histogram of Species')
plt.figure(figsize=(12, 12))
plt.show()

# %%
# Display images for different species
def plot_defects(defect_types, rows, cols):
    fig, ax = plt.subplots(rows, cols, figsize=(12, 12))
    defect_files = train['File'][train['Disease Type'] == defect_types].values
    n = 0
    for i in range(rows):
        for j in range(cols):
            image_path = os.path.join(data_dir, defect_files[n])
            ax[i, j].set_xticks([])
            ax[i, j].set_yticks([])
            ax[i, j].imshow(cv2.imread(image_path))
            n += 1
# Displays first n images of class from training set
plot_defects('Tomato_Bacterial_spot', 5, 5)

# %%
IMAGE_SIZE = 64

def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath)) # Loading a color image is the default flag
# Resize image to target size
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %%
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))
# Normalize the data
X_Train = X_train / 255.
print('Train Shape: {}'.format(X_Train.shape))
# Out:
# 16012it [02:21, 113.10it/s]
# Train Shape: (16012, 64, 64, 3)

# %%
# import cv2

# def apply_histogram_equalization(image):
#     hsv = cv2.cvtColor(image, cv2.COLOR_RGB2HSV)
#     hsv[:,:,2] = cv2.equalizeHist(hsv[:,:,2])
#     return cv2.cvtColor(hsv, cv2.COLOR_HSV2RGB)

# %%
Y_train = train['DiseaseID'].values
Y_train = to_categorical(Y_train, num_classes=15)

# %% [markdown]
# In summary, using .values converts a Pandas Series to a NumPy array, and this can be beneficial when working with certain machine learning libraries or numerical operations.

# %%
BATCH_SIZE = 64

# train 70 , val 20, test 10

# Split the train,test validation sets 
X_train, X_temp, Y_train, Y_temp = train_test_split(X_Train, Y_train, test_size=0.3, random_state=SEED)
X_test, X_val, Y_test, Y_val = train_test_split(X_temp, Y_temp, test_size=1/3, random_state = SEED)

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 15))
for i in range(3):
    ax[i].set_axis_off()
    ax[i].imshow(X_train[i])
    ax[i].set_title(disease_types[np.argmax(Y_train[i])])

# %%
EPOCHS = 50
SIZE=64
N_ch=3

# %%
def build_densenet():
    densenet = MobileNetV2(weights='imagenet', include_top=False)

    input = Input(shape=(SIZE, SIZE, N_ch))
    x = Conv2D(3, (3, 3), padding='same')(input)
    
    x = densenet(x)
    
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(512, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # multi output
    output = Dense(15,activation = 'softmax', name='root')(x)
 

    # model
    model = Model(input,output)
    
    optimizer = Adam(lr=0.002, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=0.0)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    model.summary()
    
    return model

# %%
model = build_densenet()
annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
# Generates batches of image data with data augmentation
datagen = ImageDataGenerator(rotation_range=360, # Degree range for random rotations
                        width_shift_range=0.2, # Range for random horizontal shifts
                        height_shift_range=0.2, # Range for random vertical shifts
                        zoom_range=0.2, # Range for random zoom
                        horizontal_flip=True, # Randomly flip inputs horizontally
                        vertical_flip=True) # Randomly flip inputs vertically

datagen.fit(X_train)
# Fits the model on batches with real-time data augmentation
hist = model.fit_generator(datagen.flow(X_train, Y_train, batch_size=BATCH_SIZE),
               steps_per_epoch=X_train.shape[0] // BATCH_SIZE,
               epochs=EPOCHS,
               verbose=2,
               callbacks=[annealer, checkpoint],
               validation_data=(X_val, Y_val))
# Out:
# /opt/conda/lib/python3.6/site-packages/keras_applications/mobilenet_v2.py:294: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   warnings.warn('`input_shape` is undefined or non-square, '
# Downloading data from https://github.com/JonathanCMitchell/mobilenet_v2_keras/releases/download/v1.1/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9412608/9406464 [==============================] - 0s 0us/step
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 64, 64, 3)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 64, 64, 3)         84
# _________________________________________________________________
# mobilenetv2_1.00_224 (Model) multiple                  2257984
# _________________________________________________________________
# global_average_pooling2d_3 ( (None, 1280)              0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 1280)              5120
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1280)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               655872
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# root (Dense)                 (None, 15)                7695
# =================================================================
# Total params: 2,928,803
# Trainable params: 2,891,107
# Non-trainable params: 37,696
# _________________________________________________________________
# Epoch 1/50
#  - 37s - loss: 3.2853 - accuracy: 0.1986 - val_loss: 7.8291 - val_accuracy: 0.1660
#
# Epoch 00001: val_loss improved from inf to 7.82912, saving model to model.h5
# Epoch 2/50
#  - 15s - loss: 1.8909 - accuracy: 0.4653 - val_loss: 3.8078 - val_accuracy: 0.2915
#
# Epoch 00002: val_loss improved from 7.82912 to 3.80781, saving model to model.h5
# Epoch 3/50
#  - 15s - loss: 1.3863 - accuracy: 0.5770 - val_loss: 8.8222 - val_accuracy: 0.2047
#
# Epoch 00003: val_loss did not improve from 3.80781
# Epoch 4/50
#  - 15s - loss: 1.0256 - accuracy: 0.6783 - val_loss: 10.5382 - val_accuracy: 0.2335
#
# Epoch 00004: val_loss did not improve from 3.80781
# Epoch 5/50
#  - 15s - loss: 0.8028 - accuracy: 0.7417 - val_loss: 4.3349 - val_accuracy: 0.3177
#
# Epoch 00005: val_loss did not improve from 3.80781
# Epoch 6/50
#  - 15s - loss: 0.5924 - accuracy: 0.8057 - val_loss: 5.3351 - val_accuracy: 0.3365
#
# Epoch 00006: val_loss did not improve from 3.80781
# Epoch 7/50
#  - 15s - loss: 0.5288 - accuracy: 0.8251 - val_loss: 5.4491 - val_accuracy: 0.2940
#
# Epoch 00007: val_loss did not improve from 3.80781
# Epoch 8/50
#  - 15s - loss: 0.4819 - accuracy: 0.8425 - val_loss: 4.4693 - val_accuracy: 0.3795
#
# Epoch 00008: val_loss did not improve from 3.80781
# Epoch 9/50
#  - 16s - loss: 0.3977 - accuracy: 0.8689 - val_loss: 4.8516 - val_accuracy: 0.3851
#
# Epoch 00009: val_loss did not improve from 3.80781
# Epoch 10/50
#  - 16s - loss: 0.3498 - accuracy: 0.8855 - val_loss: 3.3061 - val_accuracy: 0.4563
#
# Epoch 00010: val_loss improved from 3.80781 to 3.30608, saving model to model.h5
# Epoch 11/50
#  - 16s - loss: 0.3233 - accuracy: 0.8943 - val_loss: 2.9779 - val_accuracy: 0.5774
#
# Epoch 00011: val_loss improved from 3.30608 to 2.97789, saving model to model.h5
# Epoch 12/50
#  - 16s - loss: 0.2927 - accuracy: 0.9043 - val_loss: 3.6162 - val_accuracy: 0.5350
#
# Epoch 00012: val_loss did not improve from 2.97789
# Epoch 13/50
#  - 15s - loss: 0.2778 - accuracy: 0.9090 - val_loss: 3.1311 - val_accuracy: 0.5169
#
# Epoch 00013: val_loss did not improve from 2.97789
# Epoch 14/50
#  - 15s - loss: 0.2617 - accuracy: 0.9157 - val_loss: 2.2383 - val_accuracy: 0.5899
#
# Epoch 00014: val_loss improved from 2.97789 to 2.23828, saving model to model.h5
# Epoch 15/50
#  - 15s - loss: 0.2244 - accuracy: 0.9235 - val_loss: 1.7523 - val_accuracy: 0.6417
#
# Epoch 00015: val_loss improved from 2.23828 to 1.75232, saving model to model.h5
# Epoch 16/50
#  - 15s - loss: 0.2214 - accuracy: 0.9271 - val_loss: 2.1678 - val_accuracy: 0.5387
#
# Epoch 00016: val_loss did not improve from 1.75232
# Epoch 17/50
#  - 15s - loss: 0.2109 - accuracy: 0.9319 - val_loss: 1.5296 - val_accuracy: 0.6754
#
# Epoch 00017: val_loss improved from 1.75232 to 1.52958, saving model to model.h5
# Epoch 18/50
#  - 15s - loss: 0.2094 - accuracy: 0.9309 - val_loss: 1.2086 - val_accuracy: 0.7260
#
# Epoch 00018: val_loss improved from 1.52958 to 1.20865, saving model to model.h5
# Epoch 19/50
#  - 15s - loss: 0.1886 - accuracy: 0.9418 - val_loss: 1.0294 - val_accuracy: 0.7347
#
# Epoch 00019: val_loss improved from 1.20865 to 1.02941, saving model to model.h5
# Epoch 20/50
#  - 15s - loss: 0.1950 - accuracy: 0.9357 - val_loss: 1.0262 - val_accuracy: 0.7478
#
# Epoch 00020: val_loss improved from 1.02941 to 1.02619, saving model to model.h5
# Epoch 21/50
#  - 15s - loss: 0.1878 - accuracy: 0.9389 - val_loss: 0.7180 - val_accuracy: 0.8146
#
# Epoch 00021: val_loss improved from 1.02619 to 0.71802, saving model to model.h5
# Epoch 22/50
#  - 15s - loss: 0.1731 - accuracy: 0.9413 - val_loss: 0.6403 - val_accuracy: 0.8458
#
# Epoch 00022: val_loss improved from 0.71802 to 0.64026, saving model to model.h5
# Epoch 23/50
#  - 15s - loss: 0.1610 - accuracy: 0.9449 - val_loss: 0.4506 - val_accuracy: 0.8664
#
# Epoch 00023: val_loss improved from 0.64026 to 0.45062, saving model to model.h5
# Epoch 24/50
#  - 15s - loss: 0.1797 - accuracy: 0.9433 - val_loss: 0.3159 - val_accuracy: 0.8933
#
# Epoch 00024: val_loss improved from 0.45062 to 0.31594, saving model to model.h5
# Epoch 25/50
#  - 15s - loss: 0.1753 - accuracy: 0.9441 - val_loss: 0.9291 - val_accuracy: 0.8065
#
# Epoch 00025: val_loss did not improve from 0.31594
# Epoch 26/50
#  - 15s - loss: 0.1698 - accuracy: 0.9464 - val_loss: 0.9694 - val_accuracy: 0.7179
#
# Epoch 00026: val_loss did not improve from 0.31594
# Epoch 27/50
#  - 15s - loss: 0.1508 - accuracy: 0.9494 - val_loss: 0.4451 - val_accuracy: 0.8789
#
# Epoch 00027: val_loss did not improve from 0.31594
# Epoch 28/50
#  - 15s - loss: 0.1275 - accuracy: 0.9563 - val_loss: 1.3748 - val_accuracy: 0.7066
#
# Epoch 00028: val_loss did not improve from 0.31594
# Epoch 29/50
#  - 15s - loss: 0.1258 - accuracy: 0.9582 - val_loss: 0.5994 - val_accuracy: 0.8352
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
#
# Epoch 00029: val_loss did not improve from 0.31594
# Epoch 30/50
#  - 15s - loss: 0.1227 - accuracy: 0.9595 - val_loss: 0.1775 - val_accuracy: 0.9469
#
# Epoch 00030: val_loss improved from 0.31594 to 0.17748, saving model to model.h5
# Epoch 31/50
#  - 15s - loss: 0.1424 - accuracy: 0.9619 - val_loss: 0.4312 - val_accuracy: 0.8677
#
# Epoch 00031: val_loss did not improve from 0.17748
# Epoch 32/50
#  - 15s - loss: 0.0991 - accuracy: 0.9676 - val_loss: 0.6586 - val_accuracy: 0.8159
#
# Epoch 00032: val_loss did not improve from 0.17748
# Epoch 33/50
#  - 15s - loss: 0.1073 - accuracy: 0.9682 - val_loss: 0.5691 - val_accuracy: 0.8421
#
# Epoch 00033: val_loss did not improve from 0.17748
# Epoch 34/50
#  - 15s - loss: 0.0949 - accuracy: 0.9681 - val_loss: 0.1648 - val_accuracy: 0.9457
#
# Epoch 00034: val_loss improved from 0.17748 to 0.16484, saving model to model.h5
# Epoch 35/50
#  - 15s - loss: 0.0975 - accuracy: 0.9692 - val_loss: 0.5423 - val_accuracy: 0.8539
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00035: val_loss did not improve from 0.16484
# Epoch 36/50
#  - 15s - loss: 0.1245 - accuracy: 0.9632 - val_loss: 0.3592 - val_accuracy: 0.8864
#
# Epoch 00036: val_loss did not improve from 0.16484
# Epoch 37/50
#  - 15s - loss: 0.0995 - accuracy: 0.9703 - val_loss: 0.3900 - val_accuracy: 0.8789
#
# Epoch 00037: val_loss did not improve from 0.16484
# Epoch 38/50
#  - 15s - loss: 0.0959 - accuracy: 0.9660 - val_loss: 0.5196 - val_accuracy: 0.8421
#
# Epoch 00038: val_loss did not improve from 0.16484
# Epoch 39/50
#  - 15s - loss: 0.1026 - accuracy: 0.9693 - val_loss: 0.7037 - val_accuracy: 0.7896
#
# Epoch 00039: val_loss did not improve from 0.16484
# Epoch 40/50
#  - 15s - loss: 0.0923 - accuracy: 0.9716 - val_loss: 0.6327 - val_accuracy: 0.8184
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00040: val_loss did not improve from 0.16484
# Epoch 41/50
#  - 15s - loss: 0.0824 - accuracy: 0.9722 - val_loss: 0.2154 - val_accuracy: 0.9320
#
# Epoch 00041: val_loss did not improve from 0.16484
# Epoch 42/50
#  - 15s - loss: 0.0990 - accuracy: 0.9698 - val_loss: 0.3693 - val_accuracy: 0.8883
#
# Epoch 00042: val_loss did not improve from 0.16484
# Epoch 43/50
#  - 15s - loss: 0.0813 - accuracy: 0.9733 - val_loss: 0.3902 - val_accuracy: 0.8895
#
# Epoch 00043: val_loss did not improve from 0.16484
# Epoch 44/50
#  - 15s - loss: 0.0730 - accuracy: 0.9760 - val_loss: 0.2373 - val_accuracy: 0.9307
#
# Epoch 00044: val_loss did not improve from 0.16484
# Epoch 45/50
#  - 15s - loss: 0.0863 - accuracy: 0.9747 - val_loss: 0.2807 - val_accuracy: 0.9145
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00045: val_loss did not improve from 0.16484
# Epoch 46/50
#  - 15s - loss: 0.0942 - accuracy: 0.9716 - val_loss: 0.2182 - val_accuracy: 0.9295
#
# Epoch 00046: val_loss did not improve from 0.16484
# Epoch 47/50
#  - 15s - loss: 0.1068 - accuracy: 0.9694 - val_loss: 0.4695 - val_accuracy: 0.8689
#
# Epoch 00047: val_loss did not improve from 0.16484
# Epoch 48/50
#  - 15s - loss: 0.0723 - accuracy: 0.9753 - val_loss: 0.4874 - val_accuracy: 0.8614
#
# Epoch 00048: val_loss did not improve from 0.16484
# Epoch 49/50
#  - 15s - loss: 0.0903 - accuracy: 0.9712 - val_loss: 0.3025 - val_accuracy: 0.9076
#
# Epoch 00049: val_loss did not improve from 0.16484
# Epoch 50/50
#  - 15s - loss: 0.0724 - accuracy: 0.9759 - val_loss: 0.3396 - val_accuracy: 0.8970
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00050: val_loss did not improve from 0.16484

# %%
model = load_model('/kaggle/working/model.h5')
print(model.summary())
final_loss, final_accuracy = model.evaluate(X_test, Y_test)
print('Final Loss: {}, Final Accuracy: {}'.format(final_loss, final_accuracy))
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 64, 64, 3)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 64, 64, 3)         84
# _________________________________________________________________
# mobilenetv2_1.00_224 (Model) multiple                  2257984
# _________________________________________________________________
# global_average_pooling2d_3 ( (None, 1280)              0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 1280)              5120
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1280)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               655872
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# root (Dense)                 (None, 15)                7695
# =================================================================
# Total params: 2,928,803
# Trainable params: 2,891,107
# Non-trainable params: 37,696
# _________________________________________________________________
# None
# 3202/3202 [==============================] - 4s 1ms/step
# Final Loss: 0.16000891762141659, Final Accuracy: 0.944722056388855

# %%
# from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# # Assuming you have predictions for validation data
# Y_val_pred = model.predict(X_val)

# # Convert one-hot encoded labels to class labels
# Y_val_labels = np.argmax(Y_val, axis=1)
# Y_val_pred_labels = np.argmax(Y_val_pred, axis=1)

# # Calculate accuracy
# accuracy = accuracy_score(Y_val_labels, Y_val_pred_labels)
# print('Accuracy: {}'.format(accuracy))

# # Calculate precision, recall, and F1-score
# precision = precision_score(Y_val_labels, Y_val_pred_labels, average='weighted')
# recall = recall_score(Y_val_labels, Y_val_pred_labels, average='weighted')
# f1 = f1_score(Y_val_labels, Y_val_pred_labels, average='weighted')

# print('Precision: {}, Recall: {}, F1 Score: {}'.format(precision, recall, f1))

# # Print classification report
# class_report = classification_report(Y_val_labels, Y_val_pred_labels, target_names=disease_types)
# print('Classification Report:\n', class_report)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_auc_score, classification_report

# Assuming model.predict returns the predicted labels for your test data
Y_pred_test = model.predict(X_test)

# Convert predictions to binary labels
Y_pred_test_classes = np.argmax(Y_pred_test, axis=1)
Y_test_classes = np.argmax(Y_test, axis=1)

# Assuming you have predictions for validation data
Y_val_pred = model.predict(X_val)

# Convert one-hot encoded labels to class labels
Y_val_labels = np.argmax(Y_val, axis=1)
Y_val_pred_labels = np.argmax(Y_val_pred, axis=1)

# Calculate additional metrics
accuracy_test = accuracy_score(Y_test_classes, Y_pred_test_classes)
precision_test = precision_score(Y_test_classes, Y_pred_test_classes, average='weighted')
recall_test = recall_score(Y_test_classes, Y_pred_test_classes, average='weighted')
f1_test = f1_score(Y_test_classes, Y_pred_test_classes, average='weighted')
# roc_auc_test = roc_auc_score(Y_test_classes, Y_pred_test_classes, multi_class='ovr')
confusion_matrix_test = confusion_matrix(Y_test_classes, Y_pred_test_classes)

# Print final metrics
print('Final Loss: {}, Final Accuracy: {}, Precision: {}, Recall: {}, F1 Score: {}'
      .format(final_loss, final_accuracy, precision_test, recall_test, f1_test))
#               , roc_auc_test))

# Print Confusion Matrix
# print('\nConfusion Matrix:\n', confusion_matrix_test)

# Print classification report
class_report_train = classification_report(Y_val_labels, Y_val_pred_labels, target_names=disease_types)
print('\n\nClassification Report for Training Dataset:\n', class_report_train)

class_report_test = classification_report(Y_pred_test_classes, Y_test_classes, target_names=disease_types)
print('\n\nClassification Report for Testing Dataset:\n', class_report_test)

with open('/kaggle/working/classification_report_train.txt', 'w') as file:
    file.write(class_report_train)

with open('/kaggle/working/classification_report_test.txt', 'w') as file:
    file.write(class_report_test)
# Out:
# Final Loss: 0.16000891762141659, Final Accuracy: 0.944722056388855, Precision: 0.9509935604712972, Recall: 0.9447220487195502, F1 Score: 0.9459589173136537
#
#
# Classification Report for Training Dataset:
#                                               precision    recall  f1-score   support
#
#                       Tomato_Bacterial_spot       0.98      0.89      0.93       217
#                         Tomato_Early_blight       0.72      1.00      0.84        97
#                          Tomato_Late_blight       0.96      0.96      0.96       164
#                            Tomato_Leaf_Mold       0.91      0.97      0.94       101
#                   Tomato_Septoria_leaf_spot       0.99      0.93      0.96       198
# Tomato_Spider_mites_Two_spotted_spider_mite       0.95      0.88      0.91       163
#                         Tomato__Target_Spot       0.96      0.94      0.95       139
#       Tomato__Tomato_YellowLeaf__Curl_Virus       1.00      0.98      0.99       323
#                 Tomato__Tomato_mosaic_virus       0.97      0.92      0.95        39
#                              Tomato_healthy       0.91      0.99      0.95       161
#
#                                    accuracy                           0.95      1602
#                                   macro avg       0.94      0.95      0.94      1602
#                                weighted avg       0.95      0.95      0.95      1602
#
#
#
# Classification Report for Testing Dataset:
#                                               precision    recall  f1-score   support
#
#                       Tomato_Bacterial_spot       0.89      0.99      0.94       419
#                         Tomato_Early_blight       0.98      0.71      0.83       268
#                          Tomato_Late_blight       0.96      0.96      0.96       375
#                            Tomato_Leaf_Mold       0.98      0.95      0.96       195
#                   Tomato_Septoria_leaf_spot       0.92      0.98      0.95       314
# Tomato_Spider_mites_Two_spotted_spider_mite       0.89      0.95      0.92       308
#                         Tomato__Target_Spot       0.92      0.91      0.92       286
#       Tomato__Tomato_YellowLeaf__Curl_Virus       0.99      1.00      0.99       636
#                 Tomato__Tomato_mosaic_virus       0.95      0.97      0.96        73
#                              Tomato_healthy       0.98      0.95      0.96       328
#
#                                    accuracy                           0.94      3202
#                                   macro avg       0.95      0.94      0.94      3202
#                                weighted avg       0.95      0.94      0.94      3202

# %%
Y_pred = model.predict(X_val)

Y_pred = np.argmax(Y_pred, axis=1)
Y_true = np.argmax(Y_val, axis=1)

cm = confusion_matrix(Y_true, Y_pred)
plt.figure(figsize=(12, 12))
ax = sns.heatmap(cm, cmap=plt.cm.Greens, annot=True, square=True, xticklabels=disease_types, yticklabels=disease_types)
ax.set_ylabel('Actual', fontsize=40)
ax.set_xlabel('Predicted', fontsize=40)

plt.savefig('/kaggle/working/confusion_matrix.png')

# %%
# accuracy plot 
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.savefig('/kaggle/working/accuracy_plot.png') 
plt.show()

# loss plot
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.savefig('/kaggle/working/loss_plot.png') 
plt.show()

# %% [markdown]
# # Testing Disease Prediction

# %%
from skimage import io
from keras.preprocessing import image
#path='imbalanced/Scratch/Scratch_400.jpg'
img = image.load_img('/kaggle/input/plantdisease/PlantVillage/Tomato_healthy/01700b46-3800-46c6-ab81-09a5f50af525___RS_HL 0108.JPG', grayscale=False, target_size=(64, 64))
show_img=image.load_img('/kaggle/input/plantdisease/PlantVillage/Tomato_healthy/01700b46-3800-46c6-ab81-09a5f50af525___RS_HL 0108.JPG', grayscale=False, target_size=(200, 200))
disease_class = ['Tomato_Bacterial_spot','Tomato_Early_blight','Tomato_Late_blight','Tomato_Leaf_Mold','Tomato_Septoria_leaf_spot','Tomato_Spider_mites_Two_spotted_spider_mite','Tomato__Target_Spot','Tomato__Tomato_YellowLeaf__Curl_Virus','Tomato__Tomato_mosaic_virus','Tomato_healthy']
x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
#x = np.array(x, 'float32')
x /= 255

custom = model.predict(x)
print(custom[0])



#x = x.reshape([64, 64]);

#plt.gray()
plt.imshow(show_img)
plt.savefig('/kaggle/working/prediction_plot.png')
plt.show()

a=custom[0]
ind=np.argmax(a)
        
print('Prediction:',disease_class[ind])
# Out:
# [1.85007183e-11 2.39228507e-06 7.06865748e-08 1.21917310e-06
#  9.96262372e-01 1.01319376e-10 2.46939668e-03 5.57573075e-15
#  1.05867393e-05 1.11695437e-03 8.47790852e-06 2.88911042e-06
#  4.78017355e-05 3.42336534e-05 4.35884394e-05]
# Prediction: Tomato_Septoria_leaf_spot

# %%
# import urllib.request

# # Set the figure size for the plot
# plt.figure(figsize=(15, 15))

# # Load the trained model
# # model = load_model('/kaggle/working/my_model.h5')

# # Define the image URL
# img_url = "https://www.google.com/imgres?imgurl=https%3A%2F%2Fdoorcountypulse.com%2Fwp-content%2Fuploads%2F2017%2F02%2FEarly-blight.jpg&tbnid=OkaWKnZbFZDOpM&vet=12ahUKEwicpIyAgJyDAxXme2wGHfUrAYwQMygRegQIARBk..i&imgrefurl=https%3A%2F%2Fdoorcountypulse.com%2Fpest-profile-septoria-leaf-spot-early-blight-tomatoes%2F&docid=lj3g3J2UvP1WiM&w=780&h=519&q=tomato%20leaf%20disease%20images%20namely&hl=en&ved=2ahUKEwicpIyAgJyDAxXme2wGHfUrAYwQMygRegQIARBk"

# # Download the image and save it to a file
# filename, headers = urllib.request.urlretrieve(img_url)
# img_path = os.path.join(os.getcwd(), filename)

# try:
#     # Load and preprocess the image
#     img = image.load_img(img_path, target_size=(224, 224))
#     img = image.img_to_array(img)
#     img = np.expand_dims(img, axis=0)
#     # Perform further processing as needed
#     # ...
# except Exception as e:
#     print(f"Error loading the image: {e}")


# # # Load and preprocess the image
# # img = image.load_img(img_path, target_size=(224, 224))
# # img = image.img_to_array(img)
# # img = np.expand_dims(img, axis=0)

# # Predict the class probabilities
# probs = model.predict(img)[0]

# # Get the predicted class index and name
# pred_class_prob = np.argmax(probs)
# pred_class_name = disease_types[pred_class_prob]

# # Print the predicted class name and probability
# print(f'Predicted class: {pred_class_name}')
# print(f'Probability: {probs[pred_class_prob]}')

# # Display the image with the predicted class and probability
# plt.imshow(img[0]/255.)
# plt.axis('off')
# plt.text(10, 20, f'Predicted class: {pred_class_name}\nProbability: {probs[pred_class_prob]:.2f}', fontsize=20, color='red', bbox=dict(facecolor='white', alpha=0.8))
# plt.show()

# %%
# # Load the trained model (uncomment and provide the correct path)
# # model = load_model('/kaggle/working/model.h5')

# # Define the image URL (replace with a direct image URL)
# # img_url = "https://www.google.com/imgres?imgurl=https%3A%2F%2Fdoorcountypulse.com%2Fwp-content%2Fuploads%2F2017%2F02%2FEarly-blight.jpg&tbnid=OkaWKnZbFZDOpM&vet=12ahUKEwicpIyAgJyDAxXme2wGHfUrAYwQMygRegQIARBk..i&imgrefurl=https%3A%2F%2Fdoorcountypulse.com%2Fpest-profile-septoria-leaf-spot-early-blight-tomatoes%2F&docid=lj3g3J2UvP1WiM&w=780&h=519&q=tomato%20leaf%20disease%20images%20namely&hl=en&ved=2ahUKEwicpIyAgJyDAxXme2wGHfUrAYwQMygRegQIARBk"
# # img_url = "https://doorcountypulse.com/wp-content/uploads/2017/02/Early-blight.jpg"

# img_url = "data:image/jpeg;base64,..."

# # Download the image and save it to a file
# filename, headers = urllib.request.urlretrieve(img_url)
# img_path = os.path.join(os.getcwd(), filename)

# try:
#     # Load and preprocess the image
#     img = image.load_img(img_path, target_size=(224, 224))
#     img = image.img_to_array(img)
#     img = np.expand_dims(img, axis=0)
# except Exception as e:
#     print(f"Error loading the image: {e}")

# # Predict the class probabilities
# probs = model.predict(img)[0]

# # Get the predicted class index and name
# pred_class_prob = np.argmax(probs)
# pred_class_name = disease_types[pred_class_prob]

# # Print the predicted class name and probability
# print(f'Predicted class: {pred_class_name}')
# print(f'Probability: {probs[pred_class_prob]}')

# # Display the image with the predicted class and probability
# plt.figure(figsize=(8, 8))
# plt.imshow(img[0] / 255.)
# plt.axis('off')
# plt.text(
#     10, 20,
#     f'Predicted class: {pred_class_name}\nProbability: {probs[pred_class_prob]:.2f}',
#     fontsize=12, color='red', bbox=dict(facecolor='white', alpha=0.8)
# )
# plt.show()
